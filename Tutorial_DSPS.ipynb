# %%
# !git clone 'https://github.com/UM-Titan/DSPS23.git'

# %%
# %cd DSPS23/

# %%
# !pip install -U --no-cache-dir gdown --pre

# %%
## uncomment line below to download training data
# !gdown '16C6l-CcWEbxFYgarbbKFvK19e-0UYsT2'
# !unzip 'training_data.zip' -d './'

# %%
import os
from simple_fxn import cvat2yolo
# location of cvat annotations
if not os.path.isdir('training_data/'):
  print ('Training Data Missing')

if not os.path.isdir('yolo_data/'):
  os.makedirs('yolo_data')
annotation_folder = 'training_data/'
output_path = 'yolo_data/training'
val_path = 'yolo_data/validation'
for annts in os.listdir(annotation_folder):
  json_file = os.path.join(annotation_folder,annts,'annotations','instances_default.json')
  img_path = os.path.join(annotation_folder,annts,'images')
  if(os.path.isfile(json_file)):
    cvat2yolo(annts,json_file,img_path, output_path, val_path)
# Out:
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['BLOCK', 'ALLIGATOR', 'SEALING', 'TRANSVERSE', 'LONGITUDINAL', 'MANHOLE', 'PATCHING']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['LONGITUDINAL', 'BLOCK', 'TRANSVERSE', 'MANHOLE', 'PATCHING', 'ALLIGATOR']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['PATCHING', 'TRANSVERSE', 'ALLIGATOR', 'LONGITUDINAL', 'BLOCK', 'SEALING']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['SEALING', 'LONGITUDINAL', 'BLOCK', 'ALLIGATOR', 'TRANSVERSE', 'PATCHING']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['LONGITUDINAL', 'TRANSVERSE', 'BLOCK', 'PATCHING', 'ALLIGATOR', 'MANHOLE', 'SEALING']

# %%
# !python train_dsps.py --data data/dsps.yaml --epochs 300 --weights yolov5s.pt --cfg yolov5s.yaml  --batch-size 64
# Out:
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitpython
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.29 smmap-5.0.0
#
# requirements: 1 package updated per ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# train_dsps: weights=yolov5s.pt, cfg=yolov5s.yaml, data=data/dsps.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# requirements: YOLOv5 requirements "ipython" "thop>=0.1.1" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (7.9.0)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from thop>=0.1.1) (1.13.0+cu116)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython) (5.6.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython) (0.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->thop>=0.1.1) (4.4.0)
# Installing collected packages: jedi, thop
# Successfully installed jedi-0.18.2 thop-0.1.1.post2209072238
#
# requirements: 2 packages updated per /content/drive/MyDrive/dev/DSPS23/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-12-11 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 118MB/s]
# Overriding model.yaml nc=80 with nc=7
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     32364  models.yolo.Detect                      [7, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7038508 parameters, 7038508 gradients
#
# Transferred 342/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/dev/DSPS23/yolov5/yolo_data/training... 628 images, 60 backgrounds, 0 corrupt: 100% 688/688 [00:03<00:00, 201.19it/s]
# train: New cache created: /content/drive/MyDrive/dev/DSPS23/yolov5/yolo_data/training.cache
# val: Scanning /content/drive/MyDrive/dev/DSPS23/yolov5/yolo_data/validation... 155 images, 14 backgrounds, 0 corrupt: 100% 169/169 [00:01<00:00, 128.58it/s]
# val: New cache created: /content/drive/MyDrive/dev/DSPS23/yolov5/yolo_data/validation.cache
#
# AutoAnchor: 3.47 anchors/target, 0.978 Best Possible Recall (BPR). Anchors are a poor fit to dataset ⚠️, attempting to improve...
# AutoAnchor: Running kmeans for 9 anchors on 1855 points...
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.6880: 100% 1000/1000 [00:01<00:00, 560.51it/s]
# AutoAnchor: thr=0.25: 0.9995 best possible recall, 3.37 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.252/0.688-mean/best, past_thr=0.471-mean: 58,23, 27,75, 118,34, 27,217, 247,49, 103,122, 43,503, 208,454, 546,609
# AutoAnchor: Done ✅ (optional: update model *.yaml to use these anchors in the future)
# Plotting labels to runs/train/exp2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299        14G     0.1118    0.03597     0.0583        251        640: 100% 11/11 [01:07<00:00,  6.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.65s/it]
#                    all        169        437    0.00107      0.155    0.00099   0.000262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299      12.1G    0.09827    0.03621    0.05148        264        640: 100% 11/11 [01:00<00:00,  5.53s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.23s/it]
#                    all        169        437    0.00159      0.221     0.0147    0.00508
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299      13.5G    0.08567    0.03974    0.04456        289        640: 100% 11/11 [01:12<00:00,  6.61s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.39s/it]
#                    all        169        437      0.733     0.0649     0.0268     0.0113
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299      13.5G    0.07841     0.0414    0.03984        309        640: 100% 11/11 [01:00<00:00,  5.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.85s/it]
#                    all        169        437      0.742     0.0594     0.0365     0.0152
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299      13.5G     0.0726    0.04172      0.037        270        640: 100% 11/11 [01:08<00:00,  6.21s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:05<00:00,  2.70s/it]
#                    all        169        437      0.685      0.107     0.0866     0.0381
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299      13.5G    0.06894    0.04157    0.03527        304        640: 100% 11/11 [00:58<00:00,  5.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:05<00:00,  2.80s/it]
#                    all        169        437      0.548     0.0979      0.062     0.0206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299      13.5G    0.06618    0.03799    0.03258        301        640: 100% 11/11 [01:12<00:00,  6.56s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:04<00:00,  2.20s/it]
#                    all        169        437      0.766      0.103      0.184     0.0913
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299      13.5G    0.06535    0.03656    0.03184        299        640: 100% 11/11 [00:59<00:00,  5.40s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:04<00:00,  2.02s/it]
#                    all        169        437      0.392       0.25       0.16     0.0617
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299      13.5G    0.06405     0.0355    0.02814        246        640: 100% 11/11 [01:07<00:00,  6.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:04<00:00,  2.21s/it]
#                    all        169        437      0.405      0.245      0.153     0.0573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299      13.5G    0.06202    0.03454    0.02559        235        640: 100% 11/11 [00:59<00:00,  5.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.83s/it]
#                    all        169        437      0.371      0.207       0.15     0.0604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299      13.5G    0.06027    0.03413    0.02397        299        640: 100% 11/11 [01:11<00:00,  6.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:05<00:00,  2.78s/it]
#                    all        169        437      0.136      0.272      0.163     0.0743
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299      13.5G     0.0577    0.03362    0.02209        273        640: 100% 11/11 [01:00<00:00,  5.48s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:06<00:00,  3.21s/it]
#                    all        169        437      0.224      0.288      0.218      0.096
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299      13.5G     0.0574    0.03311    0.02153        273        640: 100% 11/11 [01:05<00:00,  5.92s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.80s/it]
#                    all        169        437      0.329       0.33      0.194     0.0845
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299      13.5G    0.05512    0.03212     0.0198        249        640: 100% 11/11 [00:59<00:00,  5.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.72s/it]
#                    all        169        437      0.309      0.296      0.254      0.109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299      13.5G    0.05512    0.03562    0.01946        279        640: 100% 11/11 [01:06<00:00,  6.06s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:04<00:00,  2.44s/it]
#                    all        169        437      0.364      0.324      0.235     0.0954
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299      13.5G    0.05422    0.03431    0.01872        284        640: 100% 11/11 [01:02<00:00,  5.67s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.51s/it]
#                    all        169        437      0.284       0.32       0.26      0.114
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299      13.5G    0.05258     0.0329    0.01756        234        640: 100% 11/11 [01:06<00:00,  6.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.90s/it]
#                    all        169        437      0.388      0.364      0.319      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/299      13.5G    0.05154    0.03288    0.01742        276        640: 100% 11/11 [00:59<00:00,  5.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.80s/it]
#                    all        169        437      0.366      0.347      0.313      0.153
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/299      13.5G    0.05156    0.03252    0.01673        281        640: 100% 11/11 [01:06<00:00,  6.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.42s/it]
#                    all        169        437      0.347      0.409      0.357      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/299      13.5G     0.0499    0.03347    0.01543        265        640: 100% 11/11 [01:05<00:00,  5.98s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.38s/it]
#                    all        169        437      0.307      0.305      0.281      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/299      13.5G    0.04896    0.03403    0.01551        290        640: 100% 11/11 [01:07<00:00,  6.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.42s/it]
#                    all        169        437      0.401       0.39      0.339      0.158
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/299      13.5G    0.04922    0.03169    0.01496        261        640: 100% 11/11 [01:01<00:00,  5.59s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.32s/it]
#                    all        169        437      0.381      0.397      0.334      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/299      13.5G    0.04909    0.03112    0.01485        249        640: 100% 11/11 [01:08<00:00,  6.27s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.38s/it]
#                    all        169        437      0.508      0.344       0.37      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/299      13.5G    0.04825    0.03278    0.01481        253        640: 100% 11/11 [01:04<00:00,  5.90s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.30s/it]
#                    all        169        437       0.56      0.361      0.382      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/299      13.5G    0.04684    0.03249    0.01431        345        640:  36% 4/11 [00:25<00:37,  5.35s/it]

# %%
# !ls
# Out:
# data		__pycache__	  train_dsps.py        val.py
# detect_dsps.py	requirements.txt  training_data        yolo_data
# export.py	runs		  training_data.zip    yolov5s.pt
# hubconf.py	setup.cfg	  Tutorial_DSPS.ipynb
# models		simple_fxn.py	  utils

# %%
## uncomment to download  test data
# !gdown '1vhaDLAK39pXTLbGFp8nW4dDxKWispzg_'
# !unzip 'test_data.zip' -d './'

# %%
# !python detect_dsps.py --weights runs/train/exp/weights/best.pt --source 'test_data/'
# Out:
# detect_dsps: weights=['runs/train/exp/weights/best.pt'], source=test_data/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2022-12-11 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7029004 parameters, 0 gradients
# image 1/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (1).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, 2 LONGITUDINALs, 16.8ms
# image 2/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (10).JPG: 640x352 3 ALLIGATORs, 1 PATCHING, 8.8ms
# image 3/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (100).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 SEALING, 17.5ms
# image 4/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (101).JPG: 640x352 1 MANHOLE, 15.9ms
# image 5/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (102).JPG: 640x352 1 TRANSVERSE, 2 LONGITUDINALs, 8.8ms
# image 6/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (103).JPG: 640x352 5 ALLIGATORs, 1 PATCHING, 10.3ms
# image 7/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (104).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, 9.8ms
# image 8/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (105).JPG: 640x352 1 TRANSVERSE, 8.8ms
# image 9/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (106).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 1 PATCHING, 8.8ms
# image 10/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (107).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 11/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (108).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, 1 PATCHING, 8.8ms
# image 12/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (109).JPG: 640x352 2 BLOCKs, 1 TRANSVERSE, 1 PATCHING, 2 MANHOLEs, 8.8ms
# image 13/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (11).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 1 LONGITUDINAL, 8.9ms
# image 14/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (110).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 PATCHING, 1 LONGITUDINAL, 9.0ms
# image 15/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (111).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, 11.4ms
# image 16/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (112).JPG: 640x352 1 ALLIGATOR, 9.2ms
# image 17/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (113).JPG: 640x352 1 PATCHING, 9.0ms
# image 18/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (114).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 2 LONGITUDINALs, 11.9ms
# image 19/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (115).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, 2 LONGITUDINALs, 8.9ms
# image 20/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (116).JPG: 640x352 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 21/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (117).JPG: 640x352 1 PATCHING, 3 LONGITUDINALs, 8.8ms
# image 22/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (118).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 9.4ms
# image 23/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (119).JPG: 640x352 3 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 24/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (12).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 1 PATCHING, 8.8ms
# image 25/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (120).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 26/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (121).JPG: 640x352 1 BLOCK, 3 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 27/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (122).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 28/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (123).JPG: 640x352 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 29/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (124).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 30/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (125).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 31/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (126).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 32/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (127).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 33/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (128).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 34/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (129).JPG: 640x352 3 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 35/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (13).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 1 LONGITUDINAL, 12.0ms
# image 36/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (130).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 37/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (131).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 38/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (132).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 39/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (133).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 40/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (134).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, 8.8ms
# image 41/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (135).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 42/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (136).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 43/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (137).JPG: 640x352 4 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 44/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (138).JPG: 640x352 3 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 45/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (139).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 46/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (14).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 9.0ms
# image 47/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (140).JPG: 640x352 2 PATCHINGs, 2 LONGITUDINALs, 8.9ms
# image 48/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (15).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 49/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (16).JPG: 640x352 1 ALLIGATOR, 2 PATCHINGs, 1 LONGITUDINAL, 8.8ms
# image 50/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (17).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 51/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (18).JPG: 640x352 1 ALLIGATOR, 2 LONGITUDINALs, 8.8ms
# image 52/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (19).JPG: 640x352 1 LONGITUDINAL, 8.8ms
# image 53/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (2).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 PATCHING, 8.8ms
# image 54/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (20).JPG: 640x352 1 ALLIGATOR, 3 PATCHINGs, 8.8ms
# image 55/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (21).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 8.8ms
# image 56/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (22).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 8.8ms
# image 57/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (23).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 9.0ms
# image 58/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (24).JPG: 640x352 1 ALLIGATOR, 2 PATCHINGs, 13.6ms
# image 59/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (25).JPG: 640x352 1 ALLIGATOR, 5 PATCHINGs, 8.8ms
# image 60/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (26).JPG: 640x352 2 ALLIGATORs, 3 PATCHINGs, 8.8ms
# image 61/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (27).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 8.8ms
# image 62/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (28).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 8.8ms
# image 63/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (29).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 8.8ms
# image 64/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (3).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 PATCHING, 8.8ms
# image 65/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (30).JPG: 640x352 1 ALLIGATOR, 2 PATCHINGs, 8.8ms
# image 66/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (31).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 9.3ms
# image 67/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (32).JPG: 640x352 3 ALLIGATORs, 1 PATCHING, 8.8ms
# image 68/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (33).JPG: 640x352 4 ALLIGATORs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 69/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (34).JPG: 640x352 1 ALLIGATOR, 3 PATCHINGs, 8.8ms
# image 70/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (35).JPG: 640x352 2 ALLIGATORs, 2 PATCHINGs, 8.8ms
# image 71/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (36).JPG: 640x352 2 ALLIGATORs, 3 PATCHINGs, 1 LONGITUDINAL, 8.8ms
# image 72/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (37).JPG: 640x352 1 BLOCK, 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 73/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (38).JPG: 640x352 1 BLOCK, 1 SEALING, 11.0ms
# image 74/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (39).JPG: 640x352 1 ALLIGATOR, 1 SEALING, 8.9ms
# image 75/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (4).JPG: 640x352 1 ALLIGATOR, 3 PATCHINGs, 1 LONGITUDINAL, 8.8ms
# image 76/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (40).JPG: 640x352 1 BLOCK, 2 SEALINGs, 8.8ms
# image 77/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (41).JPG: 640x352 1 BLOCK, 2 TRANSVERSEs, 1 SEALING, 8.8ms
# image 78/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (42).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 1 SEALING, 8.8ms
# image 79/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (43).JPG: 640x352 1 SEALING, 8.8ms
# image 80/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (44).JPG: 640x352 1 BLOCK, 1 SEALING, 8.9ms
# image 81/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (45).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 SEALING, 1 LONGITUDINAL, 14.2ms
# image 82/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (46).JPG: 640x352 1 BLOCK, 2 PATCHINGs, 1 SEALING, 12.4ms
# image 83/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (47).JPG: 640x352 1 BLOCK, 1 SEALING, 2 LONGITUDINALs, 8.8ms
# image 84/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (48).JPG: 640x352 1 TRANSVERSE, 1 SEALING, 9.1ms
# image 85/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (49).JPG: 640x352 1 BLOCK, 1 SEALING, 8.8ms
# image 86/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (5).JPG: 640x352 2 ALLIGATORs, 1 PATCHING, 2 LONGITUDINALs, 14.1ms
# image 87/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (50).JPG: 640x352 2 BLOCKs, 4 TRANSVERSEs, 2 SEALINGs, 8.8ms
# image 88/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (51).JPG: 640x352 1 BLOCK, 1 SEALING, 1 LONGITUDINAL, 8.8ms
# image 89/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (52).JPG: 640x352 1 ALLIGATOR, 8.8ms
# image 90/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (53).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 8.9ms
# image 91/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (54).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 TRANSVERSE, 1 LONGITUDINAL, 11.7ms
# image 92/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (55).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, 13.6ms
# image 93/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (56).JPG: 640x352 2 ALLIGATORs, 1 LONGITUDINAL, 8.8ms
# image 94/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (57).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 MANHOLE, 8.8ms
# image 95/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (58).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 2 PATCHINGs, 1 LONGITUDINAL, 8.8ms
# image 96/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (59).JPG: 640x352 3 TRANSVERSEs, 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 97/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (6).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, 1 LONGITUDINAL, 8.9ms
# image 98/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (60).JPG: 640x352 2 TRANSVERSEs, 2 LONGITUDINALs, 1 MANHOLE, 17.9ms
# image 99/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (61).JPG: 640x352 1 ALLIGATOR, 8.8ms
# image 100/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (62).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 8.8ms
# image 101/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (63).JPG: 640x352 1 BLOCK, 2 TRANSVERSEs, 1 PATCHING, 2 LONGITUDINALs, 14.9ms
# image 102/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (64).JPG: 640x352 1 BLOCK, 2 PATCHINGs, 1 LONGITUDINAL, 8.9ms
# image 103/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (65).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 104/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (66).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 2 PATCHINGs, 2 LONGITUDINALs, 8.8ms
# image 105/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (67).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 8.9ms
# image 106/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (68).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, 8.9ms
# image 107/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (69).JPG: 640x352 1 PATCHING, 8.9ms
# image 108/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (7).JPG: 640x352 2 ALLIGATORs, 1 PATCHING, 9.4ms
# image 109/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (70).JPG: 640x352 1 TRANSVERSE, 1 MANHOLE, 9.9ms
# image 110/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (71).JPG: 640x352 1 ALLIGATOR, 3 PATCHINGs, 8.8ms
# image 111/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (72).JPG: 640x352 1 BLOCK, 1 SEALING, 1 LONGITUDINAL, 9.1ms
# image 112/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (73).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 PATCHING, 2 LONGITUDINALs, 8.8ms
# image 113/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (74).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 114/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (75).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, 2 PATCHINGs, 8.8ms
# image 115/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (76).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, 8.9ms
# image 116/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (77).JPG: 640x352 1 ALLIGATOR, 4 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 117/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (78).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, 8.8ms
# image 118/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (79).JPG: 640x352 3 ALLIGATORs, 2 TRANSVERSEs, 1 PATCHING, 11.2ms
# image 119/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (8).JPG: 640x352 2 ALLIGATORs, 1 PATCHING, 8.8ms
# image 120/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (80).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 2 PATCHINGs, 13.6ms
# image 121/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (81).JPG: 640x352 2 PATCHINGs, 8.8ms
# image 122/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (82).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 123/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (83).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, 8.8ms
# image 124/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (84).JPG: 640x352 3 TRANSVERSEs, 2 PATCHINGs, 1 LONGITUDINAL, 8.8ms
# image 125/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (85).JPG: 640x352 (no detections), 8.9ms
# image 126/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (86).JPG: 640x352 3 SEALINGs, 8.8ms
# image 127/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (87).JPG: 640x352 2 TRANSVERSEs, 8.8ms
# image 128/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (88).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 3 LONGITUDINALs, 8.8ms
# image 129/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (89).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 2 PATCHINGs, 2 LONGITUDINALs, 9.2ms
# image 130/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (9).JPG: 640x352 3 ALLIGATORs, 2 PATCHINGs, 8.8ms
# image 131/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (90).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 8.8ms
# image 132/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (91).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 PATCHING, 1 MANHOLE, 9.0ms
# image 133/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (92).JPG: 640x352 1 SEALING, 11.8ms
# image 134/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (93).JPG: 640x352 1 TRANSVERSE, 1 SEALING, 8.8ms
# image 135/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (94).JPG: 640x352 2 SEALINGs, 11.6ms
# image 136/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (95).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 137/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (96).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, 1 PATCHING, 8.8ms
# image 138/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (97).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 2 SEALINGs, 1 LONGITUDINAL, 8.8ms
# image 139/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (98).JPG: 640x352 2 TRANSVERSEs, 2 SEALINGs, 1 LONGITUDINAL, 8.8ms
# image 140/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/0 (99).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 SEALING, 8.8ms
# image 141/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000177106.jpg: 384x640 2 ALLIGATORs, 1 BLOCK, 1 LONGITUDINAL, 12.7ms
# image 142/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000185211.jpg: 384x640 1 PATCHING, 10.8ms
# image 143/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000193287.jpg: 384x640 1 ALLIGATOR, 1 PATCHING, 11.5ms
# image 144/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000201342.jpg: 384x640 1 ALLIGATOR, 1 BLOCK, 1 SEALING, 8.8ms
# image 145/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000209245.jpg: 384x640 (no detections), 10.9ms
# image 146/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000217557.jpg: 384x640 1 BLOCK, 8.6ms
# image 147/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000225593.jpg: 384x640 1 ALLIGATOR, 1 PATCHING, 8.9ms
# image 148/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000233593.jpg: 384x640 1 LONGITUDINAL, 8.7ms
# image 149/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000241530.jpg: 384x640 (no detections), 8.6ms
# image 150/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000249693.jpg: 384x640 1 PATCHING, 8.7ms
# image 151/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000257660.jpg: 384x640 2 LONGITUDINALs, 8.7ms
# image 152/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000265751.jpg: 384x640 2 PATCHINGs, 8.6ms
# image 153/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000273879.jpg: 384x640 1 PATCHING, 8.6ms
# image 154/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000281909.jpg: 384x640 1 PATCHING, 14.3ms
# image 155/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000289889.jpg: 384x640 (no detections), 8.8ms
# image 156/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000297865.jpg: 384x640 1 ALLIGATOR, 9.1ms
# image 157/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000305925.jpg: 384x640 1 ALLIGATOR, 8.6ms
# image 158/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000314060.jpg: 384x640 (no detections), 8.6ms
# image 159/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000321897.jpg: 384x640 (no detections), 15.1ms
# image 160/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000330270.jpg: 384x640 (no detections), 8.7ms
# image 161/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000338076.jpg: 384x640 1 PATCHING, 8.6ms
# image 162/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000346074.jpg: 384x640 1 ALLIGATOR, 8.6ms
# image 163/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000354223.jpg: 384x640 (no detections), 8.6ms
# image 164/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000362473.jpg: 384x640 1 ALLIGATOR, 1 PATCHING, 11.1ms
# image 165/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000370378.jpg: 384x640 (no detections), 9.1ms
# image 166/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000378275.jpg: 384x640 (no detections), 8.7ms
# image 167/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000386617.jpg: 384x640 (no detections), 9.0ms
# image 168/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000394444.jpg: 384x640 (no detections), 8.6ms
# image 169/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000402488.jpg: 384x640 1 LONGITUDINAL, 8.6ms
# image 170/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000410499.jpg: 384x640 (no detections), 8.6ms
# image 171/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000418623.jpg: 384x640 1 PATCHING, 8.6ms
# image 172/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000426713.jpg: 384x640 (no detections), 9.1ms
# image 173/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000434766.jpg: 384x640 2 PATCHINGs, 8.8ms
# image 174/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000442632.jpg: 384x640 1 PATCHING, 8.6ms
# image 175/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000450784.jpg: 384x640 (no detections), 8.7ms
# image 176/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000458990.jpg: 384x640 1 LONGITUDINAL, 8.7ms
# image 177/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000466756.jpg: 384x640 (no detections), 8.6ms
# image 178/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000475097.jpg: 384x640 (no detections), 8.6ms
# image 179/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000483067.jpg: 384x640 (no detections), 8.6ms
# image 180/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000491135.jpg: 384x640 1 ALLIGATOR, 8.8ms
# image 181/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000499243.jpg: 384x640 1 ALLIGATOR, 8.7ms
# image 182/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000507018.jpg: 384x640 (no detections), 8.6ms
# image 183/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000514997.jpg: 384x640 (no detections), 8.6ms
# image 184/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000523266.jpg: 384x640 1 PATCHING, 9.5ms
# image 185/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000531408.jpg: 384x640 1 ALLIGATOR, 9.2ms
# image 186/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000539312.jpg: 384x640 1 ALLIGATOR, 1 SEALING, 9.0ms
# image 187/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000547544.jpg: 384x640 (no detections), 8.8ms
# image 188/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000555286.jpg: 384x640 (no detections), 8.8ms
# image 189/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000563356.jpg: 384x640 (no detections), 8.6ms
# image 190/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000571500.jpg: 384x640 (no detections), 8.6ms
# image 191/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000579728.jpg: 384x640 (no detections), 8.6ms
# image 192/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000587625.jpg: 384x640 1 SEALING, 8.6ms
# image 193/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000595531.jpg: 384x640 1 PATCHING, 8.6ms
# image 194/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000603747.jpg: 384x640 1 BLOCK, 1 TRANSVERSE, 1 PATCHING, 8.6ms
# image 195/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000611815.jpg: 384x640 (no detections), 8.6ms
# image 196/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000619730.jpg: 384x640 1 LONGITUDINAL, 8.6ms
# image 197/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000627918.jpg: 384x640 1 LONGITUDINAL, 8.6ms
# image 198/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000635736.jpg: 384x640 2 ALLIGATORs, 1 LONGITUDINAL, 10.2ms
# image 199/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000643941.jpg: 384x640 (no detections), 9.1ms
# image 200/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000651806.jpg: 384x640 (no detections), 8.6ms
# image 201/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000660143.jpg: 384x640 1 PATCHING, 8.6ms
# image 202/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000668187.jpg: 384x640 1 PATCHING, 8.8ms
# image 203/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000676298.jpg: 384x640 1 ALLIGATOR, 10.8ms
# image 204/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000684324.jpg: 384x640 1 BLOCK, 8.6ms
# image 205/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000692255.jpg: 384x640 (no detections), 8.6ms
# image 206/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000700067.jpg: 384x640 (no detections), 12.7ms
# image 207/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000708451.jpg: 384x640 (no detections), 11.5ms
# image 208/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000716369.jpg: 384x640 1 ALLIGATOR, 1 LONGITUDINAL, 8.6ms
# image 209/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000724291.jpg: 384x640 (no detections), 8.9ms
# image 210/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000732314.jpg: 384x640 1 PATCHING, 10.1ms
# image 211/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000740511.jpg: 384x640 (no detections), 9.2ms
# image 212/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000748520.jpg: 384x640 (no detections), 12.7ms
# image 213/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000756748.jpg: 384x640 (no detections), 8.6ms
# image 214/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000764781.jpg: 384x640 (no detections), 8.9ms
# image 215/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000772549.jpg: 384x640 (no detections), 10.4ms
# image 216/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000780816.jpg: 384x640 (no detections), 8.9ms
# image 217/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000788742.jpg: 384x640 (no detections), 8.6ms
# image 218/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000796675.jpg: 384x640 (no detections), 8.6ms
# image 219/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000804989.jpg: 384x640 (no detections), 8.6ms
# image 220/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000812816.jpg: 384x640 1 PATCHING, 8.6ms
# image 221/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000821017.jpg: 384x640 1 ALLIGATOR, 8.7ms
# image 222/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000829123.jpg: 384x640 1 LONGITUDINAL, 8.6ms
# image 223/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000837205.jpg: 384x640 (no detections), 8.6ms
# image 224/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000845242.jpg: 384x640 2 ALLIGATORs, 1 BLOCK, 8.8ms
# image 225/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000853253.jpg: 384x640 1 MANHOLE, 8.7ms
# image 226/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000861233.jpg: 384x640 (no detections), 8.7ms
# image 227/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000869150.jpg: 384x640 1 PATCHING, 8.6ms
# image 228/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000877289.jpg: 384x640 (no detections), 8.6ms
# image 229/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000885234.jpg: 384x640 (no detections), 8.6ms
# image 230/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000893523.jpg: 384x640 (no detections), 8.6ms
# image 231/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000901369.jpg: 384x640 1 ALLIGATOR, 11.8ms
# image 232/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000909401.jpg: 384x640 (no detections), 8.9ms
# image 233/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000917619.jpg: 384x640 (no detections), 8.7ms
# image 234/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000925672.jpg: 384x640 (no detections), 8.6ms
# image 235/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000933642.jpg: 384x640 (no detections), 11.7ms
# image 236/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000941582.jpg: 384x640 (no detections), 8.6ms
# image 237/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000949762.jpg: 384x640 (no detections), 8.6ms
# image 238/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000957831.jpg: 384x640 (no detections), 8.6ms
# image 239/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000965719.jpg: 384x640 (no detections), 10.8ms
# image 240/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000973933.jpg: 384x640 (no detections), 8.6ms
# image 241/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000981887.jpg: 384x640 (no detections), 8.6ms
# image 242/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000989775.jpg: 384x640 1 PATCHING, 9.7ms
# image 243/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000000997991.jpg: 384x640 (no detections), 9.6ms
# image 244/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000001005864.jpg: 384x640 2 TRANSVERSEs, 8.6ms
# image 245/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000001013953.jpg: 384x640 1 ALLIGATOR, 10.0ms
# image 246/246 /content/drive/MyDrive/dev/DSPS23/dsps23/test_data/000001021972.jpg: 384x640 1 LONGITUDINAL, 8.6ms
# Speed: 0.5ms pre-process, 9.4ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# !pwd
# Out:
# /content/drive/MyDrive/dev/DSPS23/dsps23
