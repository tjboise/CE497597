# %% [markdown]
# - Switch to use GPU to run these codes. Click **Runtime** in the menu bar and then choose **change runtime type**. choose **GPU** for the **hardware accelerator** and then **Save**.
#
# - We need to connect to our own Google Drive, so that this notebook can access the files on your Google Drive.
#
# ⏰ notice: the google colab may be disconnected if he finds you are leaving the web. there are some methods to prevent this situation happen. follow this link: https://maneeshkadanasseril.medium.com/how-to-stop-colab-from-disconnecting-2021-solution-ae5721e3838

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/My Drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Then, go to the folder you uploaded.

# %%
# %cd '/content/drive/MyDrive/CE497597-main'
# Out:
# /content/drive/MyDrive/CE497597-main

# %% [markdown]
# Run the following code to train a YoloV5 model. in this tutorail, we use yolov5s as the main model, epochs 300 and batch-size 64. but of course, we can fine tune these parameters to make our model performs better.

# %%
# !python train.py --data data/CE497597.yaml --epochs 300 --weights yolov5s.pt --cfg yolov5s.yaml  --batch-size 64
# Out:
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.6 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %% [markdown]
# the results of training would be saved in the runs/train folder. ater running the train file, we can see the accuracy report from the validation dataset. Images show how many images in total in your validation dataset. Instances stands for how many defects contained. the P means precision, R means recall, mAP is mean Average Precision. the mean of mAP50 and mAP50-95 can find here: https://datascience.stackexchange.com/questions/16797/what-does-the-notation-map-5-95-mean

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source 'test_data/'
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=test_data/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-2-11 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# image 1/23 /content/drive/MyDrive/CE497597-main/test_data/0 (1).JPG: 640x352 (no detections), 13.1ms
# image 2/23 /content/drive/MyDrive/CE497597-main/test_data/0 (104).JPG: 640x352 (no detections), 8.9ms
# image 3/23 /content/drive/MyDrive/CE497597-main/test_data/0 (107).JPG: 640x352 (no detections), 9.3ms
# ...

# %% [markdown]
# the results of testing would be saved in the runs/detect folder.
